# %% [markdown]
# <a href="https://colab.research.google.com/github/ujwaljain506-hash/ml-journey/blob/main/day13_features_and_target.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/matches.csv")
print("File Loaded")
# Out:
# File Loaded

# %% [markdown]
# Day 13: Decided on features (team1, team2, venue, toss_winner, toss_decision)
# and target (winner) for the ML model. Excluded win_by_runs/win_by_wickets
# to avoid data leakage.
