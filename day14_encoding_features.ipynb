# %% [markdown]
# <a href="https://colab.research.google.com/github/ujwaljain506-hash/ml-journey/blob/main/day14_encoding_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import LabelEncoder

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/matches.csv")
print("File Loaded")
# Out:
# File Loaded

# %%
le = LabelEncoder()
df['team1_encoded'] = le.fit_transform(df['team1'])

# %%
df[['team1','team1_encoded']].head()
# Out:
#                          team1  team1_encoded
# 0          Sunrisers Hyderabad             14
# 1               Mumbai Indians              8
# 2                Gujarat Lions              4
# 3       Rising Pune Supergiant             11
# 4  Royal Challengers Bangalore             13

# %%
df['team2_encoded'] = le.fit_transform(df['team2'])

# %%
df[['team2','team2_encoded']].head()
# Out:
#                          team2  team2_encoded
# 0  Royal Challengers Bangalore             13
# 1       Rising Pune Supergiant             11
# 2        Kolkata Knight Riders              7
# 3              Kings XI Punjab              5
# 4             Delhi Daredevils              3

# %%
df['venue_encoded']=le.fit_transform(df['venue'])
df['toss_winner_encoded']=le.fit_transform(df['toss_winner'])
df['toss_decision_encoded']=le.fit_transform(df['toss_decision'])

# %%
df[['venue', 'venue_encoded', 'toss_winner', 'toss_winner_encoded', 'toss_decision', 'toss_decision_encoded']].head()
# Out:
#                                        venue  venue_encoded  \
# 0  Rajiv Gandhi International Stadium, Uppal             28
# 1    Maharashtra Cricket Association Stadium             21
# 2     Saurashtra Cricket Association Stadium             31
# 3                     Holkar Cricket Stadium             13
# 4                      M Chinnaswamy Stadium             17
#
#                    toss_winner  toss_winner_encoded toss_decision  \
# 0  Royal Challengers Bangalore                   13         field
# 1       Rising Pune Supergiant                   11         field
# 2        Kolkata Knight Riders                    7         field
# 3              Kings XI Punjab                    5         field
# 4  Royal Challengers Bangalore                   13           bat
#
#    toss_decision_encoded
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      0
