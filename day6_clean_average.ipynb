# %% [markdown]
# <a href="https://colab.research.google.com/github/ujwaljain506-hash/ml-journey/blob/main/day6_clean_average.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/matches.csv")
print("File Loaded")
# Out:
# File Loaded

# %%
df[df['win_by_runs']>0]
# Out:
#         id    Season       city        date                        team1  \
# 0        1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4        5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 8        9  IPL-2017       Pune  11-04-2017             Delhi Daredevils
# 13      14  IPL-2017    Kolkata  15-04-2017        Kolkata Knight Riders
# 14      15  IPL-2017      Delhi  15-04-2017             Delhi Daredevils
# ..     ...       ...        ...         ...                          ...
# 741  11337  IPL-2019      Delhi  28-04-2019               Delhi Capitals
# 742  11338  IPL-2019    Kolkata  28-04-2019        Kolkata Knight Riders
# 743  11339  IPL-2019  Hyderabad  29-04-2019          Sunrisers Hyderabad
# 745  11341  IPL-2019    Chennai  01-05-2019          Chennai Super Kings
# 755  11415  IPL-2019  Hyderabad  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df[df['win_by_runs'] > 0].groupby('winner')['win_by_runs'].mean()
# Out:
# winner
# Chennai Super Kings            34.192308
# Deccan Chargers                23.388889
# Delhi Capitals                 30.666667
# Delhi Daredevils               27.000000
# Gujarat Lions                   1.000000
# Kings XI Punjab                24.342105
# Kochi Tuskers Kerala           11.500000
# Kolkata Knight Riders          30.166667
# Mumbai Indians                 32.736842
# Pune Warriors                  23.166667
# Rajasthan Royals               33.148148
# Rising Pune Supergiant         24.600000
# Rising Pune Supergiants        26.500000
# Royal Challengers Bangalore    35.771429
# Sunrisers Hyderabad            23.766667
# Name: win_by_runs, dtype: float64
